# %% [markdown]
# <a href="https://colab.research.google.com/github/louis9138/136.csv/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/louis9138/136.csv/refs/heads/main/33.csv"
data = pd.read_csv(url)

x = data["YearsExperience"]
y = data["Salary"]

# %%
# !pip install wget
import wget

wget.download("https://raw.githubusercontent.com/louis9138/136.csv/refs/heads/main/33.csv")
# Out:
# ...
# '33.csv'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

plt.scatter(x, y, marker="x", color="red")
plt.title("年資-薪水")
plt.xlabel("年資")
plt.ylabel("月薪(千)")
plt.show()

# %%
def plot_pred(w, b):
  y_pred = x*w + b
  plt.plot(x, y_pred, color="blue", label="預測線")
  plt.scatter(x, y, marker="x", color="red", label="真實數據")
  plt.title("年資-薪水")
  plt.xlabel("年資")
  plt.ylabel("月薪(千)")
  plt.xlim([0, 12])
  plt.ylim([-60, 140])
  plt.legend()
  plt.show()

plot_pred(8.7, 28)
